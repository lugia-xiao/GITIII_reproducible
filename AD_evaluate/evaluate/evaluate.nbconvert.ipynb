# %%
import torch
from torch.utils.data import Dataset, DataLoader
import os
import numpy as np
import pandas as pd
import time

from model import GITIII,Loss_function
from calculate_PCC import Calculate_PCC

from dataloader import AD_evaluate_dataset

to_save_dir="../edges/"
data_dir="../../data/AD/processed1/"

ligands_info = torch.load("/".join(data_dir.split("/")[:-2]) + "/ligands.pth")
genes = torch.load("/".join(data_dir.split("/")[:-2]) + "/genes.pth")

my_model = GITIII(genes, ligands_info, node_dim=256, edge_dim=48, num_heads=2, n_layers=1, node_dim_small=16,att_dim=8)
my_model = my_model.cuda()

my_model.load_state_dict(torch.load("GRIT_best.pth"))

loss_func = Loss_function(genes, ligands_info).cuda()
evaluator=Calculate_PCC(genes,ligands_info)


cell_types_dict = {}
cnt = 0
for cell_typei in ['Astrocyte', 'Chandelier', 'Endothelial', 'L2/3 IT', 'L4 IT', 'L5 ET', 'L5 IT', 'L5/6 NP', 'L6 CT', 'L6 IT', 'L6 IT Car3', 'L6b', 'Lamp5', 'Lamp5 Lhx6', 'Microglia-PVM', 'OPC', 'Oligodendrocyte', 'Pax6', 'Pvalb', 'Sncg', 'Sst', 'Sst Chodl', 'VLMC', 'Vip']:
    cell_types_dict[cnt] = cell_typei
    cnt += 1

def evaluate_AD(sample):
    my_dataset = AD_evaluate_dataset(processed_dir=data_dir,sample=sample)
    my_dataloader = DataLoader(my_dataset, batch_size=1, num_workers=0, shuffle=False)

    length = len(my_dataloader)

    my_model.eval()

    results = []
    with torch.no_grad():
        for (stepi, x) in enumerate(my_dataloader, start=1):
            x = {k: v.cuda() for k, v in x.items()}

            cell_type_name = [cell_types_dict[int(i.cpu())] for i in x["cell_types"].squeeze(dim=0)]

            y_pred = my_model(x)
            y = x["y"]
            lossi1, lossi2 = loss_func(y_pred, y)
            lossi1 = lossi1.cpu().detach()
            lossi2 = lossi2.cpu().detach()

            attention_score = y_pred[1][0].cpu().detach()
            attention_score = attention_score.squeeze(dim=0)
            attention_score = attention_score.permute(1, 2, 0)[0, :, :]
            # print(torch.topk(attention_score[0, :], k=30, dim=-1))

            edges = y_pred[1][1].cpu().detach()
            edges = edges.squeeze(dim=0).permute(1, 2, 0)[0, :, :]

            position_x = x["position_x"].cpu().detach().squeeze(dim=0)
            position_y = x["position_y"].cpu().detach().squeeze(dim=0)

            to_save_dict = {
                "edges": edges,
                "attention_score": attention_score,
                "position_x": position_x,
                "position_y": position_y,
                "cell_type_name": cell_type_name,
                "loss_all": lossi1,
                "loss_no_interact": lossi2,
                "y_pred": y_pred[0].cpu().detach().squeeze(dim=0),
                "y": y.cpu().detach().squeeze(dim=0)
            }
            results.append(to_save_dict)

            if stepi % 2000 == 0:
                print(stepi, "/", length)
    concatenated_results = {}
    for keyi in results[0].keys():
        if keyi not in ["cell_type_name"]:
            concatenated_results[keyi] = torch.stack([results[j][keyi] for j in range(len(results))], dim=0)
        else:
            concatenated_results[keyi] = [results[j][keyi] for j in range(len(results))]
    torch.save(concatenated_results, to_save_dir + "edges_" + sample + ".pth")

    print("Finish", sample)
    return concatenated_results


if __name__ == "__main__":
    sample1 = evaluate_AD('H20.33.001.CX28.MTG.02.007.1.02.02')
    for keyi in sample1.keys():
        if keyi not in ["cell_type_name"]:
            print(keyi, sample1[keyi].shape)
        else:
            print(keyi, len(sample1[keyi]), len(sample1[keyi][0]))
# Out:
# Have samples: ['H20.33.001.CX28.MTG.02.007.1.02.02']
# There are totally 7937 cells in this dataset
# 2000 / 7937
# 4000 / 7937
# 6000 / 7937
# Finish H20.33.001.CX28.MTG.02.007.1.02.02
# edges torch.Size([7937, 49, 140])
# attention_score torch.Size([7937, 49, 140])
# position_x torch.Size([7937, 50])
# position_y torch.Size([7937, 50])
# cell_type_name 7937 50
# loss_all torch.Size([7937])
# loss_no_interact torch.Size([7937])
# y_pred torch.Size([7937, 140])
# y torch.Size([7937, 140])

# %%
samples=[]
data_dir="../../data/AD/processed1/"
for filei in os.listdir(data_dir):
    if filei.find("_TypeExp.npz") >= 0:
        samples.append(filei.split("_TypeExp.npz")[0])

for samplei in samples:
    evaluate_AD(samplei)
# Out:
# Have samples: ['H20.33.004.Cx26.MTG.02.007.1.02.04']
# There are totally 6594 cells in this dataset
# 2000 / 6594
# 4000 / 6594
# 6000 / 6594
# Finish H20.33.004.Cx26.MTG.02.007.1.02.04
# Have samples: ['H20.33.004.Cx26.MTG.02.007.1.01.04']
# There are totally 5323 cells in this dataset
# 2000 / 5323
# 4000 / 5323
# Finish H20.33.004.Cx26.MTG.02.007.1.01.04
# Have samples: ['H20.33.004.Cx26.MTG.02.007.1.01.05']
# There are totally 3157 cells in this dataset
# 2000 / 3157
# Finish H20.33.004.Cx26.MTG.02.007.1.01.05
# Have samples: ['H21.33.011.Cx26.MTG.02.007.3.01.06']
# There are totally 5406 cells in this dataset
# 2000 / 5406
# 4000 / 5406
# Finish H21.33.011.Cx26.MTG.02.007.3.01.06
# Have samples: ['H21.33.016.Cx26.MTG.02.007.3.01.01']
# There are totally 4696 cells in this dataset
# 2000 / 4696
# 4000 / 4696
# Finish H21.33.016.Cx26.MTG.02.007.3.01.01
# Have samples: ['H21.33.028.CX28.MTG.02.007.1.01.01']
# There are totally 4421 cells in this dataset
# 2000 / 4421
# 4000 / 4421
# Finish H21.33.028.CX28.MTG.02.007.1.01.01
# Have samples: ['H21.33.038.Cx20.MTG.02.007.3.01.02']
# There are totally 2413 cells in this dataset
# 2000 / 2413
# Finish H21.33.038.Cx20.MTG.02.007.3.01.02
# Have samples: ['H21.33.040.Cx22.MTG.02.007.3.03.03']
# There are totally 4873 cells in this dataset
# 2000 / 4873
# 4000 / 4873
# Finish H21.33.040.Cx22.MTG.02.007.3.03.03
# Have samples: ['H21.33.022.Cx26.MTG.02.007.2.M.02']
# There are totally 1780 cells in this dataset
# Finish H21.33.022.Cx26.MTG.02.007.2.M.02
# Have samples: ['H21.33.038.Cx20.MTG.02.007.3.01.04']
# There are totally 4125 cells in this dataset
# 2000 / 4125
# 4000 / 4125
# Finish H21.33.038.Cx20.MTG.02.007.3.01.04
# Have samples: ['H21.33.005.Cx18.MTG.02.007.02.04']
# There are totally 3702 cells in this dataset
# 2000 / 3702
# Finish H21.33.005.Cx18.MTG.02.007.02.04
# Have samples: ['H20.33.012.Cx24.MTG.02.007.1.01.01']
# There are totally 3525 cells in this dataset
# 2000 / 3525
# Finish H20.33.012.Cx24.MTG.02.007.1.01.01
# Have samples: ['H20.33.012.Cx24.MTG.02.007.1.03.03']
# There are totally 3776 cells in this dataset
# 2000 / 3776
# Finish H20.33.012.Cx24.MTG.02.007.1.03.03
# Have samples: ['H21.33.023.Cx26.MTG.02.007.1.03.01']
# There are totally 6738 cells in this dataset
# 2000 / 6738
# 4000 / 6738
# 6000 / 6738
# Finish H21.33.023.Cx26.MTG.02.007.1.03.01
# Have samples: ['H20.33.025.Cx28.MTG.02.007.1.01.02']
# There are totally 5394 cells in this dataset
# 2000 / 5394
# 4000 / 5394
# Finish H20.33.025.Cx28.MTG.02.007.1.01.02
# Have samples: ['H21.33.012.Cx26.MTG.02.007.1.01.06']
# There are totally 6844 cells in this dataset
# 2000 / 6844
# 4000 / 6844
# 6000 / 6844
# Finish H21.33.012.Cx26.MTG.02.007.1.01.06
# Have samples: ['H20.33.025.Cx28.MTG.02.007.1.01.04']
# There are totally 5063 cells in this dataset
# 2000 / 5063
# 4000 / 5063
# Finish H20.33.025.Cx28.MTG.02.007.1.01.04
# Have samples: ['H20.33.044.Cx26.MTG.02.007.1.01.04']
# There are totally 6491 cells in this dataset
# 2000 / 6491
# 4000 / 6491
# 6000 / 6491
# Finish H20.33.044.Cx26.MTG.02.007.1.01.04
# Have samples: ['H21.33.023.Cx26.MTG.02.007.1.03.05']
# There are totally 7181 cells in this dataset
# 2000 / 7181
# 4000 / 7181
# 6000 / 7181
# Finish H21.33.023.Cx26.MTG.02.007.1.03.05
# Have samples: ['H20.33.004.Cx26.MTG.02.007.1.02.03']
# There are totally 4709 cells in this dataset
# 2000 / 4709
# 4000 / 4709
# Finish H20.33.004.Cx26.MTG.02.007.1.02.03
# Have samples: ['H21.33.016.Cx26.MTG.02.007.3.01.02']
# There are totally 6229 cells in this dataset
# 2000 / 6229
# 4000 / 6229
# 6000 / 6229
# Finish H21.33.016.Cx26.MTG.02.007.3.01.02
# Have samples: ['H20.33.040.Cx25.MTG.02.007.1.01.03']
# There are totally 8654 cells in this dataset
# 2000 / 8654
# 4000 / 8654
# 6000 / 8654
# 8000 / 8654
# Finish H20.33.040.Cx25.MTG.02.007.1.01.03
# Have samples: ['H21.33.001.Cx22.MTG.02.007.1.01.04']
# There are totally 6677 cells in this dataset
# 2000 / 6677
# 4000 / 6677
# 6000 / 6677
# Finish H21.33.001.Cx22.MTG.02.007.1.01.04
# Have samples: ['H20.33.012.Cx24.MTG.02.007.1.03.02']
# There are totally 3192 cells in this dataset
# 2000 / 3192
# Finish H20.33.012.Cx24.MTG.02.007.1.03.02
# Have samples: ['H21.33.015.Cx26.MTG.02.007.1.2']
# There are totally 8057 cells in this dataset
# 2000 / 8057
# 4000 / 8057
# 6000 / 8057
# 8000 / 8057
# Finish H21.33.015.Cx26.MTG.02.007.1.2
# Have samples: ['H21.33.022.Cx26.MTG.02.007.2.M.03']
# There are totally 2225 cells in this dataset
# 2000 / 2225
# Finish H21.33.022.Cx26.MTG.02.007.2.M.03
# Have samples: ['H21.33.005.Cx18.MTG.02.007.02.03']
# There are totally 2117 cells in this dataset
# 2000 / 2117
# Finish H21.33.005.Cx18.MTG.02.007.02.03
# Have samples: ['H21.33.032.CX24.MTG.02.007.1.01.04']
# There are totally 4940 cells in this dataset
# 2000 / 4940
# 4000 / 4940
# Finish H21.33.032.CX24.MTG.02.007.1.01.04
# Have samples: ['H21.33.022.Cx26.MTG.02.007.2.M.04']
# There are totally 2276 cells in this dataset
# 2000 / 2276
# Finish H21.33.022.Cx26.MTG.02.007.2.M.04
# Have samples: ['H21.33.006.Cx28.MTG.02.007.1.01.09.03']
# There are totally 765 cells in this dataset
# Finish H21.33.006.Cx28.MTG.02.007.1.01.09.03
# Have samples: ['H21.33.015.Cx26.MTG.02.007.1.0']
# There are totally 7573 cells in this dataset
# 2000 / 7573
# 4000 / 7573
# 6000 / 7573
# Finish H21.33.015.Cx26.MTG.02.007.1.0
# Have samples: ['H20.33.035.Cx26.MTG.02.007.1.01.03']
# There are totally 6060 cells in this dataset
# 2000 / 6060
# 4000 / 6060
# 6000 / 6060
# Finish H20.33.035.Cx26.MTG.02.007.1.01.03
# Have samples: ['H20.33.015.Cx24.MTG.02.007.1.03.03']
# There are totally 5924 cells in this dataset
# 2000 / 5924
# 4000 / 5924
# Finish H20.33.015.Cx24.MTG.02.007.1.03.03
# Have samples: ['H21.33.021.Cx26.MTG.02.007.1.04']
# There are totally 4829 cells in this dataset
# 2000 / 4829
# 4000 / 4829
# Finish H21.33.021.Cx26.MTG.02.007.1.04
# Have samples: ['H21.33.025.CX26.MTG.02.007.4.01.04']
# There are totally 2693 cells in this dataset
# 2000 / 2693
# Finish H21.33.025.CX26.MTG.02.007.4.01.04
# Have samples: ['H20.33.025.Cx28.MTG.02.007.1.01.06']
# There are totally 3441 cells in this dataset
# 2000 / 3441
# Finish H20.33.025.Cx28.MTG.02.007.1.01.06
# Have samples: ['H21.33.014.CX26.MTG.02.007.1.02.02']
# There are totally 4112 cells in this dataset
# 2000 / 4112
# 4000 / 4112
# Finish H21.33.014.CX26.MTG.02.007.1.02.02
# Have samples: ['H21.33.040.Cx22.MTG.02.007.3.03.01']
# There are totally 5795 cells in this dataset
# 2000 / 5795
# 4000 / 5795
# Finish H21.33.040.Cx22.MTG.02.007.3.03.01
# Have samples: ['H21.33.016.Cx26.MTG.02.007.3.01.03']
# There are totally 5600 cells in this dataset
# 2000 / 5600
# 4000 / 5600
# Finish H21.33.016.Cx26.MTG.02.007.3.01.03
# Have samples: ['H21.33.021.Cx26.MTG.02.007.1.06']
# There are totally 3627 cells in this dataset
# 2000 / 3627
# Finish H21.33.021.Cx26.MTG.02.007.1.06
# Have samples: ['H21.33.013.Cx24.MTG.02.007.1.06']
# There are totally 2220 cells in this dataset
# 2000 / 2220
# Finish H21.33.013.Cx24.MTG.02.007.1.06
# Have samples: ['H21.33.015.Cx26.MTG.02.007.1.1']
# There are totally 11091 cells in this dataset
# 2000 / 11091
# 4000 / 11091
# 6000 / 11091
# 8000 / 11091
# 10000 / 11091
# Finish H21.33.015.Cx26.MTG.02.007.1.1
# Have samples: ['H20.33.001.CX28.MTG.02.007.1.02.03']
# There are totally 15222 cells in this dataset
# 2000 / 15222
# 4000 / 15222
# 6000 / 15222
# 8000 / 15222
# 10000 / 15222
# 12000 / 15222
# 14000 / 15222
# Finish H20.33.001.CX28.MTG.02.007.1.02.03
# Have samples: ['H21.33.028.Cx28.MTG.02.007.1.02.04']
# There are totally 2995 cells in this dataset
# 2000 / 2995
# Finish H21.33.028.Cx28.MTG.02.007.1.02.04
# Have samples: ['H21.33.019.Cx30.MTG.02.007.5.01.02']
# There are totally 5271 cells in this dataset
# 2000 / 5271
# 4000 / 5271
# Finish H21.33.019.Cx30.MTG.02.007.5.01.02
# Have samples: ['H20.33.044.Cx26.MTG.02.007.1.01.03']
# There are totally 5124 cells in this dataset
# 2000 / 5124
# 4000 / 5124
# Finish H20.33.044.Cx26.MTG.02.007.1.01.03
# Have samples: ['H21.33.011.Cx26.MTG.02.007.3.01.04']
# There are totally 6523 cells in this dataset
# 2000 / 6523
# 4000 / 6523
# 6000 / 6523
# Finish H21.33.011.Cx26.MTG.02.007.3.01.04
# Have samples: ['H21.33.006.Cx28.MTG.02.007.1.01.09.04']
# There are totally 2908 cells in this dataset
# 2000 / 2908
# Finish H21.33.006.Cx28.MTG.02.007.1.01.09.04
# Have samples: ['H21.33.025.CX26.MTG.02.007.4.01.06']
# There are totally 1918 cells in this dataset
# Finish H21.33.025.CX26.MTG.02.007.4.01.06
# Have samples: ['H21.33.012.Cx26.MTG.02.007.1.01.05']
# There are totally 7458 cells in this dataset
# 2000 / 7458
# 4000 / 7458
# 6000 / 7458
# Finish H21.33.012.Cx26.MTG.02.007.1.01.05
# Have samples: ['H20.33.015.CX24.MTG.02.007.1.03.01']
# There are totally 6500 cells in this dataset
# 2000 / 6500
# 4000 / 6500
# 6000 / 6500
# Finish H20.33.015.CX24.MTG.02.007.1.03.01
# Have samples: ['H21.33.019.Cx30.MTG.02.007.5.0']
# There are totally 4025 cells in this dataset
# 2000 / 4025
# 4000 / 4025
# Finish H21.33.019.Cx30.MTG.02.007.5.0
# Have samples: ['H20.33.035.Cx26.MTG.02.007.1.01.04']
# There are totally 4407 cells in this dataset
# 2000 / 4407
# 4000 / 4407
# Finish H20.33.035.Cx26.MTG.02.007.1.01.04
# Have samples: ['H21.33.012.Cx26.MTG.02.007.1.01.04']
# There are totally 5727 cells in this dataset
# 2000 / 5727
# 4000 / 5727
# Finish H21.33.012.Cx26.MTG.02.007.1.01.04
# Have samples: ['H21.33.031.CX24.MTG.02.007.1.01.01']
# There are totally 9014 cells in this dataset
# 2000 / 9014
# 4000 / 9014
# 6000 / 9014
# 8000 / 9014
# Finish H21.33.031.CX24.MTG.02.007.1.01.01
# Have samples: ['H21.33.040.Cx22.MTG.02.007.3.03.04']
# There are totally 8895 cells in this dataset
# 2000 / 8895
# 4000 / 8895
# 6000 / 8895
# 8000 / 8895
# Finish H21.33.040.Cx22.MTG.02.007.3.03.04
# Have samples: ['H20.33.015.CX24.MTG.02.007.1.03.02']
# There are totally 3007 cells in this dataset
# 2000 / 3007
# Finish H20.33.015.CX24.MTG.02.007.1.03.02
# Have samples: ['H21.33.028.Cx28.MTG.02.007.1.02.02']
# There are totally 3305 cells in this dataset
# 2000 / 3305
# Finish H21.33.028.Cx28.MTG.02.007.1.02.02
# Have samples: ['H21.33.011.Cx26.MTG.02.007.3.01.05']
# There are totally 6340 cells in this dataset
# 2000 / 6340
# 4000 / 6340
# 6000 / 6340
# Finish H21.33.011.Cx26.MTG.02.007.3.01.05
# Have samples: ['H20.33.004.Cx26.MTG.02.007.1.02.02']
# There are totally 4120 cells in this dataset
# 2000 / 4120
# 4000 / 4120
# Finish H20.33.004.Cx26.MTG.02.007.1.02.02
# Have samples: ['H21.33.023.Cx26.MTG.02.007.1.03.04']
# There are totally 8304 cells in this dataset
# 2000 / 8304
# 4000 / 8304
# 6000 / 8304
# 8000 / 8304
# Finish H21.33.023.Cx26.MTG.02.007.1.03.04
# Have samples: ['H21.33.031.CX24.MTG.02.007.1.01.02']
# There are totally 8563 cells in this dataset
# 2000 / 8563
# 4000 / 8563
# 6000 / 8563
# 8000 / 8563
# Finish H21.33.031.CX24.MTG.02.007.1.01.02
# Have samples: ['H20.33.001.CX28.MTG.02.007.1.02.02']
# There are totally 7937 cells in this dataset
# 2000 / 7937
# 4000 / 7937
# 6000 / 7937
# Finish H20.33.001.CX28.MTG.02.007.1.02.02
# Have samples: ['H21.33.006.Cx28.MTG.02.007.1.01.09.02']
# There are totally 1952 cells in this dataset
# Finish H21.33.006.Cx28.MTG.02.007.1.01.09.02
# Have samples: ['H20.33.001.Cx28.MTG.02.007.1.01.03']
# There are totally 6680 cells in this dataset
# 2000 / 6680
# 4000 / 6680
# 6000 / 6680
# Finish H20.33.001.Cx28.MTG.02.007.1.01.03
# Have samples: ['H21.33.025.CX26.MTG.02.007.4.01.02']
# There are totally 3012 cells in this dataset
# 2000 / 3012
# Finish H21.33.025.CX26.MTG.02.007.4.01.02
# Have samples: ['H20.33.040.Cx25.MTG.02.007.1.01.04']
# There are totally 8916 cells in this dataset
# 2000 / 8916
# 4000 / 8916
# 6000 / 8916
# 8000 / 8916
# Finish H20.33.040.Cx25.MTG.02.007.1.01.04
# Have samples: ['H21.33.001.Cx22.MTG.02.007.1.01.03']
# There are totally 10469 cells in this dataset
# 2000 / 10469
# 4000 / 10469
# 6000 / 10469
# 8000 / 10469
# 10000 / 10469
# Finish H21.33.001.Cx22.MTG.02.007.1.01.03
# Have samples: ['H20.33.044.Cx26.MTG.02.007.1.01.02']
# There are totally 3040 cells in this dataset
# 2000 / 3040
# Finish H20.33.044.Cx26.MTG.02.007.1.01.02

# %%
import os
samples=[]
for filei in os.listdir(data_dir):
    if filei.find("_TypeExp.npz") >= 0:
        samples.append(filei.split("_TypeExp.npz")[0])
print(samples, "H21.33.019.Cx30.MTG.02.007.5.01.01" in samples)
# Out:
# ['H20.33.004.Cx26.MTG.02.007.1.02.04', 'H20.33.004.Cx26.MTG.02.007.1.01.04', 'H20.33.004.Cx26.MTG.02.007.1.01.05', 'H21.33.011.Cx26.MTG.02.007.3.01.06', 'H21.33.016.Cx26.MTG.02.007.3.01.01', 'H21.33.028.CX28.MTG.02.007.1.01.01', 'H21.33.038.Cx20.MTG.02.007.3.01.02', 'H21.33.040.Cx22.MTG.02.007.3.03.03', 'H21.33.022.Cx26.MTG.02.007.2.M.02', 'H21.33.038.Cx20.MTG.02.007.3.01.04', 'H21.33.005.Cx18.MTG.02.007.02.04', 'H20.33.012.Cx24.MTG.02.007.1.01.01', 'H20.33.012.Cx24.MTG.02.007.1.03.03', 'H21.33.023.Cx26.MTG.02.007.1.03.01', 'H20.33.025.Cx28.MTG.02.007.1.01.02', 'H21.33.012.Cx26.MTG.02.007.1.01.06', 'H20.33.025.Cx28.MTG.02.007.1.01.04', 'H20.33.044.Cx26.MTG.02.007.1.01.04', 'H21.33.023.Cx26.MTG.02.007.1.03.05', 'H20.33.004.Cx26.MTG.02.007.1.02.03', 'H21.33.016.Cx26.MTG.02.007.3.01.02', 'H20.33.040.Cx25.MTG.02.007.1.01.03', 'H21.33.001.Cx22.MTG.02.007.1.01.04', 'H20.33.012.Cx24.MTG.02.007.1.03.02', 'H21.33.015.Cx26.MTG.02.007.1.2', 'H21.33.022.Cx26.MTG.02.007.2.M.03', 'H21.33.005.Cx18.MTG.02.007.02.03', 'H21.33.032.CX24.MTG.02.007.1.01.04', 'H21.33.022.Cx26.MTG.02.007.2.M.04', 'H21.33.006.Cx28.MTG.02.007.1.01.09.03', 'H21.33.015.Cx26.MTG.02.007.1.0', 'H20.33.035.Cx26.MTG.02.007.1.01.03', 'H20.33.015.Cx24.MTG.02.007.1.03.03', 'H21.33.021.Cx26.MTG.02.007.1.04', 'H21.33.025.CX26.MTG.02.007.4.01.04', 'H20.33.025.Cx28.MTG.02.007.1.01.06', 'H21.33.014.CX26.MTG.02.007.1.02.02', 'H21.33.040.Cx22.MTG.02.007.3.03.01', 'H21.33.016.Cx26.MTG.02.007.3.01.03', 'H21.33.021.Cx26.MTG.02.007.1.06', 'H21.33.013.Cx24.MTG.02.007.1.06', 'H21.33.015.Cx26.MTG.02.007.1.1', 'H20.33.001.CX28.MTG.02.007.1.02.03', 'H21.33.028.Cx28.MTG.02.007.1.02.04', 'H21.33.019.Cx30.MTG.02.007.5.01.02', 'H20.33.044.Cx26.MTG.02.007.1.01.03', 'H21.33.011.Cx26.MTG.02.007.3.01.04', 'H21.33.006.Cx28.MTG.02.007.1.01.09.04', 'H21.33.025.CX26.MTG.02.007.4.01.06', 'H21.33.012.Cx26.MTG.02.007.1.01.05', 'H20.33.015.CX24.MTG.02.007.1.03.01', 'H21.33.019.Cx30.MTG.02.007.5.0', 'H20.33.035.Cx26.MTG.02.007.1.01.04', 'H21.33.012.Cx26.MTG.02.007.1.01.04', 'H21.33.031.CX24.MTG.02.007.1.01.01', 'H21.33.040.Cx22.MTG.02.007.3.03.04', 'H20.33.015.CX24.MTG.02.007.1.03.02', 'H21.33.028.Cx28.MTG.02.007.1.02.02', 'H21.33.011.Cx26.MTG.02.007.3.01.05', 'H20.33.004.Cx26.MTG.02.007.1.02.02', 'H21.33.023.Cx26.MTG.02.007.1.03.04', 'H21.33.031.CX24.MTG.02.007.1.01.02', 'H20.33.001.CX28.MTG.02.007.1.02.02', 'H21.33.006.Cx28.MTG.02.007.1.01.09.02', 'H20.33.001.Cx28.MTG.02.007.1.01.03', 'H21.33.025.CX26.MTG.02.007.4.01.02', 'H20.33.040.Cx25.MTG.02.007.1.01.04', 'H21.33.001.Cx22.MTG.02.007.1.01.03', 'H20.33.044.Cx26.MTG.02.007.1.01.02'] False
