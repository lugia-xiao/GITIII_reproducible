# %%
# Suppose that your data path is:
df_path="../data/BIDCell.csv"

genes=['ABCC11', 'ACTA2', 'ACTG2', 'ADAM9', 'ADGRE5', 'ADH1B', 'ADIPOQ', 'AGR3', 'AHSP', 'AIF1', 'AKR1C1', 'AKR1C3', 'ALDH1A3', 'ANGPT2', 'ANKRD28', 'ANKRD29', 'ANKRD30A', 'APOBEC3A', 'APOBEC3B', 'APOC1', 'AQP1', 'AQP3', 'AR', 'AVPR1A', 'BACE2', 'BANK1', 'BASP1', 'BTNL9', 'C15orf48', 'C1QA', 'C1QC', 'C2orf42', 'C5orf46', 'C6orf132', 'CAV1', 'CAVIN2', 'CCDC6', 'CCDC80', 'CCL20', 'CCL5', 'CCL8', 'CCND1', 'CCPG1', 'CCR7', 'CD14', 'CD163', 'CD19', 'CD1C', 'CD247', 'CD27', 'CD274', 'CD3D', 'CD3E', 'CD3G', 'CD4', 'CD68', 'CD69', 'CD79A', 'CD79B', 'CD80', 'CD83', 'CD86', 'CD8A', 'CD8B', 'CD9', 'CD93', 'CDC42EP1', 'CDH1', 'CEACAM6', 'CEACAM8', 'CENPF', 'CLCA2', 'CLDN4', 'CLDN5', 'CLEC14A', 'CLEC9A', 'CLECL1', 'CLIC6', 'CPA3', 'CRHBP', 'CRISPLD2', 'CSF3', 'CTH', 'CTLA4', 'CTSG', 'CTTN', 'CX3CR1', 'CXCL12', 'CXCL16', 'CXCL5', 'CXCR4', 'CYP1A1', 'CYTIP', 'DAPK3', 'DERL3', 'DMKN', 'DNAAF1', 'DNTTIP1', 'DPT', 'DSC2', 'DSP', 'DST', 'DUSP2', 'DUSP5', 'EDN1', 'EDNRB', 'EGFL7', 'EGFR', 'EIF4EBP1', 'ELF3', 'ELF5', 'ENAH', 'EPCAM', 'ERBB2', 'ERN1', 'ESM1', 'ESR1', 'FAM107B', 'FAM49A', 'FASN', 'FBLIM1', 'FBLN1', 'FCER1A', 'FCER1G', 'FCGR3A', 'FGL2', 'FLNB', 'FOXA1', 'FOXC2', 'FOXP3', 'FSTL3', 'GATA3', 'GJB2', 'GLIPR1', 'GNLY', 'GPR183', 'GZMA', 'GZMB', 'GZMK', 'HAVCR2', 'HDC', 'HMGA1', 'HOOK2', 'HOXD8', 'HOXD9', 'HPX', 'IGF1', 'IGSF6', 'IL2RA', 'IL2RG', 'IL3RA', 'IL7R', 'ITGAM', 'ITGAX', 'ITM2C', 'JUP', 'KARS', 'KDR', 'KIT', 'KLF5', 'KLRB1', 'KLRC1', 'KLRD1', 'KLRF1', 'KRT14', 'KRT15', 'KRT16', 'KRT23', 'KRT5', 'KRT6B', 'KRT7', 'KRT8', 'LAG3', 'LARS', 'LDHB', 'LEP', 'LGALSL', 'LIF', 'LILRA4', 'LPL', 'LPXN', 'LRRC15', 'LTB', 'LUM', 'LY86', 'LYPD3', 'LYZ', 'MAP3K8', 'MDM2', 'MEDAG', 'MKI67', 'MLPH', 'MMP1', 'MMP12', 'MMP2', 'MMRN2', 'MNDA', 'MPO', 'MRC1', 'MS4A1', 'MUC6', 'MYBPC1', 'MYH11', 'MYLK', 'MYO5B', 'MZB1', 'NARS', 'NCAM1', 'NDUFA4L2', 'NKG7', 'NOSTRIN', 'NPM3', 'OCIAD2', 'OPRPN', 'OXTR', 'PCLAF', 'PCOLCE', 'PDCD1', 'PDCD1LG2', 'PDE4A', 'PDGFRA', 'PDGFRB', 'PDK4', 'PECAM1', 'PELI1', 'PGR', 'PIGR', 'PIM1', 'PLD4', 'POLR2J3', 'POSTN', 'PPARG', 'PRDM1', 'PRF1', 'PTGDS', 'PTN', 'PTPRC', 'PTRHD1', 'QARS', 'RAB30', 'RAMP2', 'RAPGEF3', 'REXO4', 'RHOH', 'RORC', 'RTKN2', 'RUNX1', 'S100A14', 'S100A4', 'S100A8', 'SCD', 'SCGB2A1', 'SDC4', 'SEC11C', 'SEC24A', 'SELL', 'SERHL2', 'SERPINA3', 'SERPINB9', 'SFRP1', 'SFRP4', 'SH3YL1', 'SLAMF1', 'SLAMF7', 'SLC25A37', 'SLC4A1', 'SLC5A6', 'SMAP2', 'SMS', 'SNAI1', 'SOX17', 'SOX18', 'SPIB', 'SQLE', 'SRPK1', 'SSTR2', 'STC1', 'SVIL', 'TAC1', 'TACSTD2', 'TCEAL7', 'TCF15', 'TCF4', 'TCF7', 'TCIM', 'TCL1A', 'TENT5C', 'TFAP2A', 'THAP2', 'TIFA', 'TIGIT', 'TIMP4', 'TMEM147', 'TNFRSF17', 'TOMM7', 'TOP2A', 'TPD52', 'TPSAB1', 'TRAC', 'TRAF4', 'TRAPPC3', 'TRIB1', 'TUBA4A', 'TUBB2B', 'TYROBP', 'UCP1', 'USP53', 'VOPP1', 'VWF', 'WARS', 'ZEB1', 'ZEB2', 'ZNF562']

# %%
import torch
import numpy as np
import random
import os
import scanpy as sc

def set_random_seed(seed: int):
    # Set seed for Python's built-in random module
    random.seed(seed)
    
    # Set seed for NumPy
    np.random.seed(seed)
    
    # Set seed for PyTorch (both CPU and GPU)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)  # if using multi-GPU.
    
    # Ensure deterministic behavior in PyTorch
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

    # Optionally set the seed for Scanpy (if any stochastic behavior occurs)
    sc.settings.n_jobs = 1  # To avoid parallel execution randomness
    
    # Set the environment variable for deterministic behavior
    os.environ['PYTHONHASHSEED'] = str(seed)

    print(f"Random seed set to {seed} for reproducibility.")

# Example usage:
set_random_seed(42)
# Out:
# Random seed set to 42 for reproducibility.

# %% [markdown]
# # Basic analysis

# %%
import gitiii

sample='sample01'

spatial_visualizer=gitiii.spatial_visualizer.Spatial_visualizer(sample=sample)
# Out:
# Start loading data
# There are 106224 cells in this sample
# Finish loading data

# %%
spatial_visualizer.plot_distance_scaler(rank_or_distance="distance",proportion_or_abs="abs",target_gene=None,bins=300, frac=0.003)
spatial_visualizer.plot_distance_scaler(rank_or_distance="rank",proportion_or_abs="proportion",target_gene=None,bins=300, frac=0.003)
# Out:
# loss: tensor(0.0970)
# random: tensor(0.1109)
# first 5: tensor(0.1089)
# first 10: tensor(0.1084)
# first 20: tensor(0.1080)
# loss: tensor(0.0970)
# random: tensor(0.1109)
# first 5: tensor(0.1089)
# first 10: tensor(0.1084)
# first 20: tensor(0.1080)

# %%
spatial_visualizer.visualize_CCI_function(select_topk=5,num_type_pair=10)
# Out:
# number of cell types in this sample: (array(['ACTA2+ Myoepi', 'B Cells', 'CD163+ Macrophage', 'CD4 T', 'CD8 T',
#        'CRABP2+ Malignant', 'ECM1+ Malignant', 'Fibroblast', 'IRF7+ DC',
#        'KRT15+ Myoepi', 'LAMP3+ DC', 'Macrophage', 'Mast cells', 'Plasma',
#        'SCGB2A2+ Malignant', 'STAB2+ Endothelial', 'VWF+ Endothelial',
#        'unassigned'], dtype='<U18'), array([ 2796,  1065,  5214, 13451,  4706,  8122, 20695, 18826,   397,
#         1640,    82, 10367,   166,  2494,  8893,   106,  7191,    13]))
# selecting edge types: ['ECM1+ Malignant->ECM1+ Malignant' 'Fibroblast->ECM1+ Malignant'
#  'SCGB2A2+ Malignant->SCGB2A2+ Malignant' 'CD163+ Macrophage->Fibroblast'
#  'CRABP2+ Malignant->CRABP2+ Malignant' 'Macrophage->Fibroblast'
#  'CD4 T->CD4 T' 'Fibroblast->Fibroblast' 'Fibroblast->Macrophage'
#  'Macrophage->CD4 T']
# /home/xx244/.conda/envs/benchmark/lib/python3.11/site-packages/gitiii/spatial_visualizer.py:52: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   flag = [adata.obs['cell_type'][i] in select_type for i in range(adata.shape[0])]
# /home/xx244/.conda/envs/benchmark/lib/python3.11/site-packages/scanpy/preprocessing/_scale.py:318: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# selecting edge types: ['ECM1+ Malignant->ECM1+ Malignant' 'Fibroblast->ECM1+ Malignant'
#  'SCGB2A2+ Malignant->SCGB2A2+ Malignant' 'CD163+ Macrophage->Fibroblast'
#  'CRABP2+ Malignant->CRABP2+ Malignant' 'Macrophage->Fibroblast'
#  'CD4 T->CD4 T' 'Fibroblast->Fibroblast' 'Fibroblast->Macrophage'
#  'Macrophage->CD4 T']
# /home/xx244/.conda/envs/benchmark/lib/python3.11/site-packages/gitiii/spatial_visualizer.py:52: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   flag = [adata.obs['cell_type'][i] in select_type for i in range(adata.shape[0])]
# /home/xx244/.conda/envs/benchmark/lib/python3.11/site-packages/scanpy/preprocessing/_scale.py:318: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %% [markdown]
# # Cell subgrouping analysis for 'Macrophage'

# %%
subtyping_analyzer1=gitiii.subtyping_analyzer.Subtyping_anlayzer(sample=sample,normalize_to_1=True,use_abs=False,noise_threshold=2e-2)
# Out:
# Start loading data
# Finish loading data
# Start aggregating
# 0 / 106224
# 500 / 106224
# 1000 / 106224
# 1500 / 106224
# 2000 / 106224
# 2500 / 106224
# 3000 / 106224
# 3500 / 106224
# 4000 / 106224
# 4500 / 106224
# 5000 / 106224
# 5500 / 106224
# 6000 / 106224
# 6500 / 106224
# 7000 / 106224
# 7500 / 106224
# 8000 / 106224
# 8500 / 106224
# 9000 / 106224
# 9500 / 106224
# 10000 / 106224
# 10500 / 106224
# 11000 / 106224
# 11500 / 106224
# 12000 / 106224
# 12500 / 106224
# 13000 / 106224
# 13500 / 106224
# 14000 / 106224
# 14500 / 106224
# 15000 / 106224
# 15500 / 106224
# 16000 / 106224
# 16500 / 106224
# 17000 / 106224
# 17500 / 106224
# 18000 / 106224
# 18500 / 106224
# 19000 / 106224
# 19500 / 106224
# 20000 / 106224
# 20500 / 106224
# 21000 / 106224
# 21500 / 106224
# 22000 / 106224
# 22500 / 106224
# 23000 / 106224
# 23500 / 106224
# 24000 / 106224
# 24500 / 106224
# 25000 / 106224
# 25500 / 106224
# 26000 / 106224
# 26500 / 106224
# 27000 / 106224
# 27500 / 106224
# 28000 / 106224
# 28500 / 106224
# 29000 / 106224
# 29500 / 106224
# 30000 / 106224
# 30500 / 106224
# 31000 / 106224
# 31500 / 106224
# 32000 / 106224
# 32500 / 106224
# 33000 / 106224
# 33500 / 106224
# 34000 / 106224
# 34500 / 106224
# 35000 / 106224
# 35500 / 106224
# 36000 / 106224
# 36500 / 106224
# 37000 / 106224
# 37500 / 106224
# 38000 / 106224
# 38500 / 106224
# 39000 / 106224
# 39500 / 106224
# 40000 / 106224
# 40500 / 106224
# 41000 / 106224
# 41500 / 106224
# 42000 / 106224
# 42500 / 106224
# 43000 / 106224
# 43500 / 106224
# 44000 / 106224
# 44500 / 106224
# 45000 / 106224
# 45500 / 106224
# 46000 / 106224
# 46500 / 106224
# 47000 / 106224
# 47500 / 106224
# 48000 / 106224
# 48500 / 106224
# 49000 / 106224
# 49500 / 106224
# 50000 / 106224
# 50500 / 106224
# 51000 / 106224
# 51500 / 106224
# 52000 / 106224
# 52500 / 106224
# 53000 / 106224
# 53500 / 106224
# 54000 / 106224
# 54500 / 106224
# 55000 / 106224
# 55500 / 106224
# 56000 / 106224
# 56500 / 106224
# 57000 / 106224
# 57500 / 106224
# 58000 / 106224
# 58500 / 106224
# 59000 / 106224
# 59500 / 106224
# 60000 / 106224
# 60500 / 106224
# 61000 / 106224
# 61500 / 106224
# 62000 / 106224
# 62500 / 106224
# 63000 / 106224
# 63500 / 106224
# 64000 / 106224
# 64500 / 106224
# 65000 / 106224
# 65500 / 106224
# 66000 / 106224
# 66500 / 106224
# 67000 / 106224
# 67500 / 106224
# 68000 / 106224
# 68500 / 106224
# 69000 / 106224
# 69500 / 106224
# 70000 / 106224
# 70500 / 106224
# 71000 / 106224
# 71500 / 106224
# 72000 / 106224
# 72500 / 106224
# 73000 / 106224
# 73500 / 106224
# 74000 / 106224
# 74500 / 106224
# 75000 / 106224
# 75500 / 106224
# 76000 / 106224
# 76500 / 106224
# 77000 / 106224
# 77500 / 106224
# 78000 / 106224
# 78500 / 106224
# 79000 / 106224
# 79500 / 106224
# 80000 / 106224
# 80500 / 106224
# 81000 / 106224
# 81500 / 106224
# 82000 / 106224
# 82500 / 106224
# 83000 / 106224
# 83500 / 106224
# 84000 / 106224
# 84500 / 106224
# 85000 / 106224
# 85500 / 106224
# 86000 / 106224
# 86500 / 106224
# 87000 / 106224
# 87500 / 106224
# 88000 / 106224
# 88500 / 106224
# 89000 / 106224
# 89500 / 106224
# 90000 / 106224
# 90500 / 106224
# 91000 / 106224
# 91500 / 106224
# 92000 / 106224
# 92500 / 106224
# 93000 / 106224
# 93500 / 106224
# 94000 / 106224
# 94500 / 106224
# 95000 / 106224
# 95500 / 106224
# 96000 / 106224
# 96500 / 106224
# 97000 / 106224
# 97500 / 106224
# 98000 / 106224
# 98500 / 106224
# 99000 / 106224
# 99500 / 106224
# 100000 / 106224
# 100500 / 106224
# 101000 / 106224
# 101500 / 106224
# 102000 / 106224
# 102500 / 106224
# 103000 / 106224
# 103500 / 106224
# 104000 / 106224
# 104500 / 106224
# 105000 / 106224
# 105500 / 106224
# 106000 / 106224
# Finish aggregating

# %%
COI='Macrophage' # Cell Of Interest
subtyping_analyzer1.subtyping(COI=COI,resolution=0.2)
print("="*10)
print("="*10)
print("="*10)
print("="*10)
subtyping_analyzer1.subtyping_DE()
print("="*10)
print("="*10)
print("="*10)
print("="*10)
subtyping_analyzer1.subtyping_get_aggregated_influence()
# Out:
# /home/xx244/.conda/envs/benchmark/lib/python3.11/site-packages/scanpy/preprocessing/_pca.py:314: ImplicitModificationWarning: Setting element `.obsm['X_pca']` of view, initializing view as actual.
#   adata.obsm[key_obsm] = X_pca
# /home/xx244/.conda/envs/benchmark/lib/python3.11/site-packages/gitiii/subtyping_analyzer.py:154: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(self.adata_type, resolution=resolution)  # or sc.tl.louvain(adata)
# ==========
# ==========
# ==========
# ==========
# WARNING: dendrogram data not found (using key=dendrogram_leiden). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.
# /home/xx244/.conda/envs/benchmark/lib/python3.11/site-packages/scanpy/tools/_utils.py:41: UserWarning: You’re trying to run this on 313 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
#   warnings.warn(
# ==========
# ==========
# ==========
# ==========
# WARNING: dendrogram data not found (using key=dendrogram_leiden). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.

# %% [markdown]
# # Cell subgrouping analysis for 'Fibroblast'

# %%
subtyping_analyzer2=gitiii.subtyping_analyzer.Subtyping_anlayzer(sample=sample,normalize_to_1=True,use_abs=True,noise_threshold=2e-2)
# Out:
# Start loading data
# Finish loading data
# Start aggregating
# 0 / 106224
# 500 / 106224
# 1000 / 106224
# 1500 / 106224
# 2000 / 106224
# 2500 / 106224
# 3000 / 106224
# 3500 / 106224
# 4000 / 106224
# 4500 / 106224
# 5000 / 106224
# 5500 / 106224
# 6000 / 106224
# 6500 / 106224
# 7000 / 106224
# 7500 / 106224
# 8000 / 106224
# 8500 / 106224
# 9000 / 106224
# 9500 / 106224
# 10000 / 106224
# 10500 / 106224
# 11000 / 106224
# 11500 / 106224
# 12000 / 106224
# 12500 / 106224
# 13000 / 106224
# 13500 / 106224
# 14000 / 106224
# 14500 / 106224
# 15000 / 106224
# 15500 / 106224
# 16000 / 106224
# 16500 / 106224
# 17000 / 106224
# 17500 / 106224
# 18000 / 106224
# 18500 / 106224
# 19000 / 106224
# 19500 / 106224
# 20000 / 106224
# 20500 / 106224
# 21000 / 106224
# 21500 / 106224
# 22000 / 106224
# 22500 / 106224
# 23000 / 106224
# 23500 / 106224
# 24000 / 106224
# 24500 / 106224
# 25000 / 106224
# 25500 / 106224
# 26000 / 106224
# 26500 / 106224
# 27000 / 106224
# 27500 / 106224
# 28000 / 106224
# 28500 / 106224
# 29000 / 106224
# 29500 / 106224
# 30000 / 106224
# 30500 / 106224
# 31000 / 106224
# 31500 / 106224
# 32000 / 106224
# 32500 / 106224
# 33000 / 106224
# 33500 / 106224
# 34000 / 106224
# 34500 / 106224
# 35000 / 106224
# 35500 / 106224
# 36000 / 106224
# 36500 / 106224
# 37000 / 106224
# 37500 / 106224
# 38000 / 106224
# 38500 / 106224
# 39000 / 106224
# 39500 / 106224
# 40000 / 106224
# 40500 / 106224
# 41000 / 106224
# 41500 / 106224
# 42000 / 106224
# 42500 / 106224
# 43000 / 106224
# 43500 / 106224
# 44000 / 106224
# 44500 / 106224
# 45000 / 106224
# 45500 / 106224
# 46000 / 106224
# 46500 / 106224
# 47000 / 106224
# 47500 / 106224
# 48000 / 106224
# 48500 / 106224
# 49000 / 106224
# 49500 / 106224
# 50000 / 106224
# 50500 / 106224
# 51000 / 106224
# 51500 / 106224
# 52000 / 106224
# 52500 / 106224
# 53000 / 106224
# 53500 / 106224
# 54000 / 106224
# 54500 / 106224
# 55000 / 106224
# 55500 / 106224
# 56000 / 106224
# 56500 / 106224
# 57000 / 106224
# 57500 / 106224
# 58000 / 106224
# 58500 / 106224
# 59000 / 106224
# 59500 / 106224
# 60000 / 106224
# 60500 / 106224
# 61000 / 106224
# 61500 / 106224
# 62000 / 106224
# 62500 / 106224
# 63000 / 106224
# 63500 / 106224
# 64000 / 106224
# 64500 / 106224
# 65000 / 106224
# 65500 / 106224
# 66000 / 106224
# 66500 / 106224
# 67000 / 106224
# 67500 / 106224
# 68000 / 106224
# 68500 / 106224
# 69000 / 106224
# 69500 / 106224
# 70000 / 106224
# 70500 / 106224
# 71000 / 106224
# 71500 / 106224
# 72000 / 106224
# 72500 / 106224
# 73000 / 106224
# 73500 / 106224
# 74000 / 106224
# 74500 / 106224
# 75000 / 106224
# 75500 / 106224
# 76000 / 106224
# 76500 / 106224
# 77000 / 106224
# 77500 / 106224
# 78000 / 106224
# 78500 / 106224
# 79000 / 106224
# 79500 / 106224
# 80000 / 106224
# 80500 / 106224
# 81000 / 106224
# 81500 / 106224
# 82000 / 106224
# 82500 / 106224
# 83000 / 106224
# 83500 / 106224
# 84000 / 106224
# 84500 / 106224
# 85000 / 106224
# 85500 / 106224
# 86000 / 106224
# 86500 / 106224
# 87000 / 106224
# 87500 / 106224
# 88000 / 106224
# 88500 / 106224
# 89000 / 106224
# 89500 / 106224
# 90000 / 106224
# 90500 / 106224
# 91000 / 106224
# 91500 / 106224
# 92000 / 106224
# 92500 / 106224
# 93000 / 106224
# 93500 / 106224
# 94000 / 106224
# 94500 / 106224
# 95000 / 106224
# 95500 / 106224
# 96000 / 106224
# 96500 / 106224
# 97000 / 106224
# 97500 / 106224
# 98000 / 106224
# 98500 / 106224
# 99000 / 106224
# 99500 / 106224
# 100000 / 106224
# 100500 / 106224
# 101000 / 106224
# 101500 / 106224
# 102000 / 106224
# 102500 / 106224
# 103000 / 106224
# 103500 / 106224
# 104000 / 106224
# 104500 / 106224
# 105000 / 106224
# 105500 / 106224
# 106000 / 106224
# Finish aggregating

# %%
COI='Fibroblast' # Cell Of Interest
subtyping_analyzer2.subtyping(COI=COI,resolution=0.1)
print("="*10)
print("="*10)
print("="*10)
print("="*10)
subtyping_analyzer2.subtyping_DE()
print("="*10)
print("="*10)
print("="*10)
print("="*10)
subtyping_analyzer2.subtyping_get_aggregated_influence()
# Out:
# /home/xx244/.conda/envs/benchmark/lib/python3.11/site-packages/scanpy/preprocessing/_pca.py:314: ImplicitModificationWarning: Setting element `.obsm['X_pca']` of view, initializing view as actual.
#   adata.obsm[key_obsm] = X_pca
# ==========
# ==========
# ==========
# ==========
# WARNING: dendrogram data not found (using key=dendrogram_leiden). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.
# /home/xx244/.conda/envs/benchmark/lib/python3.11/site-packages/scanpy/tools/_utils.py:41: UserWarning: You’re trying to run this on 313 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
#   warnings.warn(
# ==========
# ==========
# ==========
# ==========
# WARNING: dendrogram data not found (using key=dendrogram_leiden). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.

# %% [markdown]
# # Cell subgrouping analysis for 'SCGB2A2+ Malignant'

# %%
subtyping_analyzer3=gitiii.subtyping_analyzer.Subtyping_anlayzer(sample=sample,normalize_to_1=True,use_abs=True,noise_threshold=2e-2)
# Out:
# Start loading data
# Finish loading data
# Start aggregating
# 0 / 106224
# 500 / 106224
# 1000 / 106224
# 1500 / 106224
# 2000 / 106224
# 2500 / 106224
# 3000 / 106224
# 3500 / 106224
# 4000 / 106224
# 4500 / 106224
# 5000 / 106224
# 5500 / 106224
# 6000 / 106224
# 6500 / 106224
# 7000 / 106224
# 7500 / 106224
# 8000 / 106224
# 8500 / 106224
# 9000 / 106224
# 9500 / 106224
# 10000 / 106224
# 10500 / 106224
# 11000 / 106224
# 11500 / 106224
# 12000 / 106224
# 12500 / 106224
# 13000 / 106224
# 13500 / 106224
# 14000 / 106224
# 14500 / 106224
# 15000 / 106224
# 15500 / 106224
# 16000 / 106224
# 16500 / 106224
# 17000 / 106224
# 17500 / 106224
# 18000 / 106224
# 18500 / 106224
# 19000 / 106224
# 19500 / 106224
# 20000 / 106224
# 20500 / 106224
# 21000 / 106224
# 21500 / 106224
# 22000 / 106224
# 22500 / 106224
# 23000 / 106224
# 23500 / 106224
# 24000 / 106224
# 24500 / 106224
# 25000 / 106224
# 25500 / 106224
# 26000 / 106224
# 26500 / 106224
# 27000 / 106224
# 27500 / 106224
# 28000 / 106224
# 28500 / 106224
# 29000 / 106224
# 29500 / 106224
# 30000 / 106224
# 30500 / 106224
# 31000 / 106224
# 31500 / 106224
# 32000 / 106224
# 32500 / 106224
# 33000 / 106224
# 33500 / 106224
# 34000 / 106224
# 34500 / 106224
# 35000 / 106224
# 35500 / 106224
# 36000 / 106224
# 36500 / 106224
# 37000 / 106224
# 37500 / 106224
# 38000 / 106224
# 38500 / 106224
# 39000 / 106224
# 39500 / 106224
# 40000 / 106224
# 40500 / 106224
# 41000 / 106224
# 41500 / 106224
# 42000 / 106224
# 42500 / 106224
# 43000 / 106224
# 43500 / 106224
# 44000 / 106224
# 44500 / 106224
# 45000 / 106224
# 45500 / 106224
# 46000 / 106224
# 46500 / 106224
# 47000 / 106224
# 47500 / 106224
# 48000 / 106224
# 48500 / 106224
# 49000 / 106224
# 49500 / 106224
# 50000 / 106224
# 50500 / 106224
# 51000 / 106224
# 51500 / 106224
# 52000 / 106224
# 52500 / 106224
# 53000 / 106224
# 53500 / 106224
# 54000 / 106224
# 54500 / 106224
# 55000 / 106224
# 55500 / 106224
# 56000 / 106224
# 56500 / 106224
# 57000 / 106224
# 57500 / 106224
# 58000 / 106224
# 58500 / 106224
# 59000 / 106224
# 59500 / 106224
# 60000 / 106224
# 60500 / 106224
# 61000 / 106224
# 61500 / 106224
# 62000 / 106224
# 62500 / 106224
# 63000 / 106224
# 63500 / 106224
# 64000 / 106224
# 64500 / 106224
# 65000 / 106224
# 65500 / 106224
# 66000 / 106224
# 66500 / 106224
# 67000 / 106224
# 67500 / 106224
# 68000 / 106224
# 68500 / 106224
# 69000 / 106224
# 69500 / 106224
# 70000 / 106224
# 70500 / 106224
# 71000 / 106224
# 71500 / 106224
# 72000 / 106224
# 72500 / 106224
# 73000 / 106224
# 73500 / 106224
# 74000 / 106224
# 74500 / 106224
# 75000 / 106224
# 75500 / 106224
# 76000 / 106224
# 76500 / 106224
# 77000 / 106224
# 77500 / 106224
# 78000 / 106224
# 78500 / 106224
# 79000 / 106224
# 79500 / 106224
# 80000 / 106224
# 80500 / 106224
# 81000 / 106224
# 81500 / 106224
# 82000 / 106224
# 82500 / 106224
# 83000 / 106224
# 83500 / 106224
# 84000 / 106224
# 84500 / 106224
# 85000 / 106224
# 85500 / 106224
# 86000 / 106224
# 86500 / 106224
# 87000 / 106224
# 87500 / 106224
# 88000 / 106224
# 88500 / 106224
# 89000 / 106224
# 89500 / 106224
# 90000 / 106224
# 90500 / 106224
# 91000 / 106224
# 91500 / 106224
# 92000 / 106224
# 92500 / 106224
# 93000 / 106224
# 93500 / 106224
# 94000 / 106224
# 94500 / 106224
# 95000 / 106224
# 95500 / 106224
# 96000 / 106224
# 96500 / 106224
# 97000 / 106224
# 97500 / 106224
# 98000 / 106224
# 98500 / 106224
# 99000 / 106224
# 99500 / 106224
# 100000 / 106224
# 100500 / 106224
# 101000 / 106224
# 101500 / 106224
# 102000 / 106224
# 102500 / 106224
# 103000 / 106224
# 103500 / 106224
# 104000 / 106224
# 104500 / 106224
# 105000 / 106224
# 105500 / 106224
# 106000 / 106224
# Finish aggregating

# %%
COI='SCGB2A2+ Malignant' # Cell Of Interest
subtyping_analyzer3.subtyping(COI=COI,resolution=0.12)
print("="*10)
print("="*10)
print("="*10)
print("="*10)
subtyping_analyzer3.subtyping_DE()
print("="*10)
print("="*10)
print("="*10)
print("="*10)
subtyping_analyzer3.subtyping_get_aggregated_influence()
# Out:
# /home/xx244/.conda/envs/benchmark/lib/python3.11/site-packages/scanpy/preprocessing/_pca.py:314: ImplicitModificationWarning: Setting element `.obsm['X_pca']` of view, initializing view as actual.
#   adata.obsm[key_obsm] = X_pca
# ==========
# ==========
# ==========
# ==========
# WARNING: dendrogram data not found (using key=dendrogram_leiden). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.
# /home/xx244/.conda/envs/benchmark/lib/python3.11/site-packages/scanpy/tools/_utils.py:41: UserWarning: You’re trying to run this on 313 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
#   warnings.warn(
# ==========
# ==========
# ==========
# ==========
# WARNING: dendrogram data not found (using key=dendrogram_leiden). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.

# %% [markdown]
# # Network analysis

# %%
network_analyzer=gitiii.network_analyzer.Network_analyzer(noise_threshold=2e-2)
# Out:
# Start loading data
# Finish loading data
# /home/xx244/.conda/envs/benchmark/lib/python3.11/site-packages/gitiii/network_analyzer.py:59: UserWarning: Network visualization is performed using R, this function only calculate the z-score matrix of significant CCI network for each sample
#   warnings.warn("Network visualization is performed using R, "

# %%
network_analyzer.determine_networks()
# Out:
# Mast cells unassigned 13
# tensor(1.) tensor(inf) tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1273,
#         0.0000, 0.0000, 0.0000, 0.0000]) tensor([-0.0595, -0.0595, -0.0595, -0.0595, -0.0595, -0.0595, -0.0595, -0.0595,
#          0.7141, -0.0595, -0.0595, -0.0595, -0.0595])
# Mast cells unassigned 13
# tensor(1.) tensor(inf) tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1133,
#         0.0000, 0.0000, 0.0000, 0.0000]) tensor([-0.0595, -0.0595, -0.0595, -0.0595, -0.0595, -0.0595, -0.0595, -0.0595,
#          0.7141, -0.0595, -0.0595, -0.0595, -0.0595])
# Plasma unassigned 13
# tensor(1.) tensor(inf) tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1142,
#         0.0000, 0.0000, 0.0000, 0.0000]) tensor([-0.0595, -0.0595, -0.0595, -0.0595, -0.0595, -0.0595, -0.0595, -0.0595,
#          0.7141, -0.0595, -0.0595, -0.0595, -0.0595])
# SCGB2A2+ Malignant unassigned 13
# tensor(1.) tensor(inf) tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.0305, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000]) tensor([-0.0881, -0.0881, -0.0881, -0.0881,  1.0575, -0.0881, -0.0881, -0.0881,
#         -0.0881, -0.0881, -0.0881, -0.0881, -0.0881])
